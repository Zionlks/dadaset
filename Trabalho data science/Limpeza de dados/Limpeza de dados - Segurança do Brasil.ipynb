# %% [markdown]
# # Limpeza de Dados
#
# Os processos de limpeza e preparação de dados são muito importantes. Dados limpos, completos e organizados tornam as análises mais fáceis e confiáveis. Abaixo descrevemos alguns dos principais mecanismos para tratar dados que tenham algum problema.
#
# Execute cada célula de código abaixo para ver o resultado.

# %% [markdown]
# ## Leitura e análise inicial dos dados

# %%
#importação de bibliotecas
import pandas as pd

# %matplotlib inline

# %%
# lê o arquivo CSV

df = pd.read_excel('C:/Users/lucas.soares/Documents/Nova Pasta/SegurançaBrasil.xlsx')

# %% [markdown]
# O primeiro passo ao se analisar dados desconhecidos é visualizar algumas linhas de dados:

# %%
df.head(15)
# Out:
#    UF da ocorrências 2015 - 2022   Tipo Crime ocorrências 2015 - 2022  \
# 0                           Acre                              Estupro
# 1                           Acre                     Furto de veículo
# 2                           Acre                     Homicídio doloso
# 3                           Acre      Lesão corporal seguida de morte
# 4                           Acre       Roubo a instituição financeira
# 5                           Acre                       Roubo de carga
# 6                           Acre                     Roubo de veículo
# 7                           Acre  Roubo seguido de morte (latrocínio)
# 8                           Acre               Tentativa de homicídio
# 9                           Acre                              Estupro
# 10                          Acre                     Furto de veículo
# 11                          Acre                     Homicídio doloso
# 12                          Acre      Lesão corporal seguida de morte
# 13                          Acre       Roubo a instituição financeira
# 14                          Acre                       Roubo de carga
#
#     Ano da ocorrências 2015 - 2022  Ocorrências 2015 - 2022  \
# 0                           2022.0                       31
# 1                           2022.0                       50
# 2                           2022.0                       10
# 3                           2022.0                        0
# 4                           2022.0                        0
# 5                           2022.0                        0
# 6                           2022.0                       72
# 7                           2022.0                        0
# 8                           2022.0                       22
# 9                           2022.0                       34
# 10                          2022.0                       55
# 11                          2022.0                       10
# 12                          2022.0                        0
# 13                          2022.0                        0
# 14                          2022.0                        0
#
#    UF da ocorrências 2022          Tipo Crime ocorrências 2022  \
# 0                    Acre                              Estupro
# 1                    Acre                     Furto de veículo
# 2                    Acre                     Homicídio doloso
# 3                    Acre      Lesão corporal seguida de morte
# 4                    Acre       Roubo a instituição financeira
# 5                    Acre                       Roubo de carga
# 6                    Acre                     Roubo de veículo
# 7                    Acre  Roubo seguido de morte (latrocínio)
# 8                    Acre               Tentativa de homicídio
# 9                    Acre                              Estupro
# 10                   Acre                     Furto de veículo
# 11                   Acre                     Homicídio doloso
# 12                   Acre      Lesão corporal seguida de morte
# 13                   Acre       Roubo a instituição financeira
# 14                   Acre                       Roubo de carga
#
#     Ano da ocorrências 2022  Ocorrências 2022 UF da ocorrências 2021  \
# 0                    2022.0              31.0                   Acre
# 1                    2022.0              50.0                   Acre
# 2                    2022.0              10.0                   Acre
# 3                    2022.0               0.0                   Acre
# 4                    2022.0               0.0                   Acre
# 5                    2022.0               0.0                   Acre
# 6                    2022.0              72.0                   Acre
# 7                    2022.0               0.0                   Acre
# 8                    2022.0              22.0                   Acre
# 9                    2022.0              34.0                   Acre
# 10                   2022.0              55.0                   Acre
# 11                   2022.0              10.0                   Acre
# 12                   2022.0               0.0                   Acre
# 13                   2022.0               0.0                   Acre
# 14                   2022.0               0.0                   Acre
#
#             Tipo Crime ocorrências 2021  ...                       Tipo Crime  \
# 0        Roubo a instituição financeira  ...                 Homicídio doloso
# 1                        Roubo de carga  ...                 Homicídio doloso
# 2                      Roubo de veículo  ...                 Homicídio doloso
# 3   Roubo seguido de morte (latrocínio)  ...                 Homicídio doloso
# 4                Tentativa de homicídio  ...                 Homicídio doloso
# 5                               Estupro  ...                 Homicídio doloso
# 6                      Furto de veículo  ...                 Homicídio doloso
# 7                      Homicídio doloso  ...                 Homicídio doloso
# 8       Lesão corporal seguida de morte  ...                 Homicídio doloso
# 9        Roubo a instituição financeira  ...                 Homicídio doloso
# 10                       Roubo de carga  ...                 Homicídio doloso
# 11                     Roubo de veículo  ...                 Homicídio doloso
# 12  Roubo seguido de morte (latrocínio)  ...                 Homicídio doloso
# 13               Tentativa de homicídio  ...  Lesão corporal seguida de morte
# 14                              Estupro  ...  Lesão corporal seguida de morte
#
#     Ano do crime Sexo da Vítima Vitima do crime   Cód_IBGE  \
# 0         2022.0       Feminino             2.0  4100103.0
# 1         2022.0      Masculino             8.0  4100202.0
# 2         2022.0        Sexo NI             0.0  4100301.0
# 3         2022.0       Feminino             0.0  4100400.0
# 4         2022.0      Masculino            10.0  4100459.0
# 5         2022.0        Sexo NI             0.0  4128625.0
# 6         2022.0       Feminino             2.0  4100608.0
# 7         2022.0      Masculino            19.0  4100707.0
# 8         2022.0        Sexo NI             0.0  4100509.0
# 9         2022.0       Feminino             2.0  4100806.0
# 10        2022.0      Masculino            19.0  4100905.0
# 11        2022.0       Feminino             6.0  4101002.0
# 12        2022.0      Masculino            17.0  4101051.0
# 13        2022.0       Feminino             0.0  4101101.0
# 14        2022.0      Masculino             0.0  4101150.0
#
#               Município Sigla UF Região    Mês/Ano Vítimas
# 0                Abatiá       PR    SUL 2018-01-01     0.0
# 1          Adrianópolis       PR    SUL 2018-01-01     1.0
# 2         Agudos Do Sul       PR    SUL 2018-01-01     0.0
# 3   Almirante Tamandaré       PR    SUL 2018-01-01     6.0
# 4    Altamira Do Paraná       PR    SUL 2018-01-01     0.0
# 5          Alto Paraíso       PR    SUL 2018-01-01     0.0
# 6           Alto Paraná       PR    SUL 2018-01-01     0.0
# 7          Alto Piquiri       PR    SUL 2018-01-01     0.0
# 8               Altônia       PR    SUL 2018-01-01     3.0
# 9       Alvorada Do Sul       PR    SUL 2018-01-01     0.0
# 10              Amaporã       PR    SUL 2018-01-01     1.0
# 11               Ampére       PR    SUL 2018-01-01     0.0
# 12                Anahy       PR    SUL 2018-01-01     0.0
# 13               Andirá       PR    SUL 2018-01-01     0.0
# 14               Ângulo       PR    SUL 2018-01-01     0.0
#
# [15 rows x 27 columns]

# %% [markdown]
# O método `info` é útil para vermos quais colunas do DataFrame tiveram seus tipos de dados corretamente identificados pelo Pandas. No caso abaixo já é possível identificar alguns problemas. As colunas *quartos, suite, area, aluguel e condomínio* foram interpretadas como objetos genéricos enquanto deveriam ser numéricas. A coluna *data* deveria ser do tipo `datetype`.
#
# O método `info` também nos informa quantos valores cada coluna tem. Veja abaixo que a coluna *endereço* tem apenas 19 valores.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21418 entries, 0 to 21417
# Data columns (total 27 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   UF da ocorrências 2015 - 2022       21418 non-null  object
#  1   Tipo Crime ocorrências 2015 - 2022  21418 non-null  object
#  2   Ano da ocorrências 2015 - 2022      21417 non-null  float64
#  3   Ocorrências 2015 - 2022             21418 non-null  int64
#  4   UF da ocorrências 2022              1184 non-null   object
#  5   Tipo Crime ocorrências 2022         1184 non-null   object
#  6   Ano da ocorrências 2022             1184 non-null   float64
#  7   Ocorrências 2022                    1184 non-null   float64
#  8   UF da ocorrências 2021              2864 non-null   object
#  9   Tipo Crime ocorrências 2021         2864 non-null   object
#  10  Ano da ocorrências 2021             2864 non-null   float64
#  11  Ocorrências 2021                    2864 non-null   float64
#  12  UF da ocorrências 2020              2880 non-null   object
#  13  Tipo Crime ocorrências 2020         2880 non-null   object
#  14  Ano da ocorrências 2020             2880 non-null   float64
#  15  Ocorrências 2020                    2880 non-null   float64
#  16  UF crime                            18342 non-null  object
#  17  Tipo Crime                          18342 non-null  object
#  18  Ano do crime                        18342 non-null  float64
#  19  Sexo da Vítima                      18342 non-null  object
#  20  Vitima do crime                     18342 non-null  float64
#  21  Cód_IBGE                            21147 non-null  float64
#  22  Município                           21147 non-null  object
#  23  Sigla UF                            21147 non-null  object
#  24  Região                              21147 non-null  object
#  25  Mês/Ano                             21147 non-null  datetime64[ns]
#  26  Vítimas                             21147 non-null  float64
# dtypes: datetime64[ns](1), float64(11), int64(1), object(14)
# memory usage: 4.4+ MB

# %% [markdown]
# ## Localizando e tratando valores inválidos

# %% [markdown]
# Uma forma prática de identificar potenciais problemas é exibir todas as linhas com valores em branco (*NaN*). Abaixo podemos verificar que uma das linhas não tem o valor para a coluna *endereco*.

# %%
df[df.isna().any(axis=1)]
# Out:
#       UF da ocorrências 2015 - 2022   Tipo Crime ocorrências 2015 - 2022  \
# 1184                           Acre                              Estupro
# 1185                           Acre                     Furto de veículo
# 1186                           Acre                     Homicídio doloso
# 1187                           Acre      Lesão corporal seguida de morte
# 1188                           Acre       Roubo a instituição financeira
# ...                             ...                                  ...
# 21413                     Tocantins       Roubo a instituição financeira
# 21414                     Tocantins                       Roubo de carga
# 21415                     Tocantins                     Roubo de veículo
# 21416                     Tocantins  Roubo seguido de morte (latrocínio)
# 21417                     Tocantins               Tentativa de homicídio
#
#        Ano da ocorrências 2015 - 2022  Ocorrências 2015 - 2022  \
# 1184                           2021.0                       39
# 1185                           2021.0                       55
# 1186                           2021.0                       13
# 1187                           2021.0                        0
# 1188                           2021.0                        0
# ...                               ...                      ...
# 21413                          2015.0                        6
# 21414                          2015.0                        1
# 21415                          2015.0                       55
# 21416                          2015.0                        2
# 21417                             NaN                       42
#
#       UF da ocorrências 2022 Tipo Crime ocorrências 2022  \
# 1184                     NaN                         NaN
# 1185                     NaN                         NaN
# 1186                     NaN                         NaN
# 1187                     NaN                         NaN
# 1188                     NaN                         NaN
# ...                      ...                         ...
# 21413                    NaN                         NaN
# 21414                    NaN                         NaN
# 21415                    NaN                         NaN
# 21416                    NaN                         NaN
# 21417                    NaN                         NaN
#
#        Ano da ocorrências 2022  Ocorrências 2022 UF da ocorrências 2021  \
# 1184                       NaN               NaN     Mato Grosso do Sul
# 1185                       NaN               NaN     Mato Grosso do Sul
# 1186                       NaN               NaN     Mato Grosso do Sul
# 1187                       NaN               NaN     Mato Grosso do Sul
# 1188                       NaN               NaN     Mato Grosso do Sul
# ...                        ...               ...                    ...
# 21413                      NaN               NaN                    NaN
# 21414                      NaN               NaN                    NaN
# 21415                      NaN               NaN                    NaN
# 21416                      NaN               NaN                    NaN
# 21417                      NaN               NaN                    NaN
#
#            Tipo Crime ocorrências 2021  ...                       Tipo Crime  \
# 1184                           Estupro  ...  Lesão corporal seguida de morte
# 1185                  Furto de veículo  ...  Lesão corporal seguida de morte
# 1186                  Homicídio doloso  ...  Lesão corporal seguida de morte
# 1187   Lesão corporal seguida de morte  ...  Lesão corporal seguida de morte
# 1188    Roubo a instituição financeira  ...  Lesão corporal seguida de morte
# ...                                ...  ...                              ...
# 21413                              NaN  ...                              NaN
# 21414                              NaN  ...                              NaN
# 21415                              NaN  ...                              NaN
# 21416                              NaN  ...                              NaN
# 21417                              NaN  ...                              NaN
#
#        Ano do crime Sexo da Vítima Vitima do crime   Cód_IBGE  \
# 1184         2021.0      Masculino             0.0  4127965.0
# 1185         2021.0        Sexo NI             0.0  4128005.0
# 1186         2021.0       Feminino             0.0  4128104.0
# 1187         2021.0      Masculino             1.0  4128203.0
# 1188         2021.0        Sexo NI             0.0  4128302.0
# ...             ...            ...             ...        ...
# 21413           NaN            NaN             NaN        NaN
# 21414           NaN            NaN             NaN        NaN
# 21415           NaN            NaN             NaN        NaN
# 21416           NaN            NaN             NaN        NaN
# 21417           NaN            NaN             NaN        NaN
#
#               Município Sigla UF Região    Mês/Ano Vítimas
# 1184              Turvo       PR    SUL 2018-03-01     0.0
# 1185            Ubiratã       PR    SUL 2018-03-01     0.0
# 1186           Umuarama       PR    SUL 2018-03-01     2.0
# 1187   União Da Vitória       PR    SUL 2018-03-01     1.0
# 1188            Uniflor       PR    SUL 2018-03-01     0.0
# ...                 ...      ...    ...        ...     ...
# 21413               NaN      NaN    NaN        NaT     NaN
# 21414               NaN      NaN    NaN        NaT     NaN
# 21415               NaN      NaN    NaN        NaT     NaN
# 21416               NaN      NaN    NaN        NaT     NaN
# 21417               NaN      NaN    NaN        NaT     NaN
#
# [20234 rows x 27 columns]

# %% [markdown]
# Podemos usar o método `fillna` para substituir os valores em branco por um valor definido, neste caso a *String* "Desconhecido". Após a substituição não há mais linhas com valores em branco.

# %%
df['Ocorrências 2022'] = df['Ocorrências 2022'].fillna("Desconhecido")

df[df.isna().any(axis=1)]
# Out:
#       UF da ocorrências 2015 - 2022   Tipo Crime ocorrências 2015 - 2022  \
# 1184                           Acre                              Estupro
# 1185                           Acre                     Furto de veículo
# 1186                           Acre                     Homicídio doloso
# 1187                           Acre      Lesão corporal seguida de morte
# 1188                           Acre       Roubo a instituição financeira
# ...                             ...                                  ...
# 21413                     Tocantins       Roubo a instituição financeira
# 21414                     Tocantins                       Roubo de carga
# 21415                     Tocantins                     Roubo de veículo
# 21416                     Tocantins  Roubo seguido de morte (latrocínio)
# 21417                     Tocantins               Tentativa de homicídio
#
#        Ano da ocorrências 2015 - 2022  Ocorrências 2015 - 2022  \
# 1184                           2021.0                       39
# 1185                           2021.0                       55
# 1186                           2021.0                       13
# 1187                           2021.0                        0
# 1188                           2021.0                        0
# ...                               ...                      ...
# 21413                          2015.0                        6
# 21414                          2015.0                        1
# 21415                          2015.0                       55
# 21416                          2015.0                        2
# 21417                             NaN                       42
#
#       UF da ocorrências 2022 Tipo Crime ocorrências 2022  \
# 1184                     NaN                         NaN
# 1185                     NaN                         NaN
# 1186                     NaN                         NaN
# 1187                     NaN                         NaN
# 1188                     NaN                         NaN
# ...                      ...                         ...
# 21413                    NaN                         NaN
# 21414                    NaN                         NaN
# 21415                    NaN                         NaN
# 21416                    NaN                         NaN
# 21417                    NaN                         NaN
#
#        Ano da ocorrências 2022 Ocorrências 2022 UF da ocorrências 2021  \
# 1184                       NaN     Desconhecido     Mato Grosso do Sul
# 1185                       NaN     Desconhecido     Mato Grosso do Sul
# 1186                       NaN     Desconhecido     Mato Grosso do Sul
# 1187                       NaN     Desconhecido     Mato Grosso do Sul
# 1188                       NaN     Desconhecido     Mato Grosso do Sul
# ...                        ...              ...                    ...
# 21413                      NaN     Desconhecido                    NaN
# 21414                      NaN     Desconhecido                    NaN
# 21415                      NaN     Desconhecido                    NaN
# 21416                      NaN     Desconhecido                    NaN
# 21417                      NaN     Desconhecido                    NaN
#
#            Tipo Crime ocorrências 2021  ...                       Tipo Crime  \
# 1184                           Estupro  ...  Lesão corporal seguida de morte
# 1185                  Furto de veículo  ...  Lesão corporal seguida de morte
# 1186                  Homicídio doloso  ...  Lesão corporal seguida de morte
# 1187   Lesão corporal seguida de morte  ...  Lesão corporal seguida de morte
# 1188    Roubo a instituição financeira  ...  Lesão corporal seguida de morte
# ...                                ...  ...                              ...
# 21413                              NaN  ...                              NaN
# 21414                              NaN  ...                              NaN
# 21415                              NaN  ...                              NaN
# 21416                              NaN  ...                              NaN
# 21417                              NaN  ...                              NaN
#
#        Ano do crime Sexo da Vítima Vitima do crime   Cód_IBGE  \
# 1184         2021.0      Masculino             0.0  4127965.0
# 1185         2021.0        Sexo NI             0.0  4128005.0
# 1186         2021.0       Feminino             0.0  4128104.0
# 1187         2021.0      Masculino             1.0  4128203.0
# 1188         2021.0        Sexo NI             0.0  4128302.0
# ...             ...            ...             ...        ...
# 21413           NaN            NaN             NaN        NaN
# 21414           NaN            NaN             NaN        NaN
# 21415           NaN            NaN             NaN        NaN
# 21416           NaN            NaN             NaN        NaN
# 21417           NaN            NaN             NaN        NaN
#
#               Município Sigla UF Região    Mês/Ano Vítimas
# 1184              Turvo       PR    SUL 2018-03-01     0.0
# 1185            Ubiratã       PR    SUL 2018-03-01     0.0
# 1186           Umuarama       PR    SUL 2018-03-01     2.0
# 1187   União Da Vitória       PR    SUL 2018-03-01     1.0
# 1188            Uniflor       PR    SUL 2018-03-01     0.0
# ...                 ...      ...    ...        ...     ...
# 21413               NaN      NaN    NaN        NaT     NaN
# 21414               NaN      NaN    NaN        NaT     NaN
# 21415               NaN      NaN    NaN        NaT     NaN
# 21416               NaN      NaN    NaN        NaT     NaN
# 21417               NaN      NaN    NaN        NaT     NaN
#
# [20234 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21418 entries, 0 to 21417
# Data columns (total 27 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   UF da ocorrências 2015 - 2022       21418 non-null  object
#  1   Tipo Crime ocorrências 2015 - 2022  21418 non-null  object
#  2   Ano da ocorrências 2015 - 2022      21417 non-null  float64
#  3   Ocorrências 2015 - 2022             21418 non-null  int64
#  4   UF da ocorrências 2022              1184 non-null   object
#  5   Tipo Crime ocorrências 2022         1184 non-null   object
#  6   Ano da ocorrências 2022             1184 non-null   float64
#  7   Ocorrências 2022                    1184 non-null   float64
#  8   UF da ocorrências 2021              2864 non-null   object
#  9   Tipo Crime ocorrências 2021         2864 non-null   object
#  10  Ano da ocorrências 2021             2864 non-null   float64
#  11  Ocorrências 2021                    2864 non-null   float64
#  12  UF da ocorrências 2020              2880 non-null   object
#  13  Tipo Crime ocorrências 2020         2880 non-null   object
#  14  Ano da ocorrências 2020             2880 non-null   float64
#  15  Ocorrências 2020                    2880 non-null   float64
#  16  UF crime                            18342 non-null  object
#  17  Tipo Crime                          18342 non-null  object
#  18  Ano do crime                        18342 non-null  float64
#  19  Sexo da Vítima                      18342 non-null  object
#  20  Vitima do crime                     18342 non-null  float64
#  21  Cód_IBGE                            21147 non-null  float64
#  22  Município                           21147 non-null  object
#  23  Sigla UF                            21147 non-null  object
#  24  Região                              21147 non-null  object
#  25  Mês/Ano                             21147 non-null  datetime64[ns]
#  26  Vítimas                             21147 non-null  float64
# dtypes: datetime64[ns](1), float64(11), int64(1), object(14)
# memory usage: 4.4+ MB

# %%
df['Tipo Crime ocorrências 2015 - 2022'].unique()
# Out:
# array(['Estupro', 'Furto de veículo', 'Homicídio doloso',
#        'Lesão corporal seguida de morte',
#        'Roubo a instituição financeira', 'Roubo de carga',
#        'Roubo de veículo', 'Roubo seguido de morte (latrocínio)',
#        'Tentativa de homicídio'], dtype=object)

# %% [markdown]
# Como a linha identificada acima tem muitos valores inválidos, podemos decidir retirá-la do DataFrame. Para isso, usamos o método `drop`. Perceba que a linha não aparece mais no DataFrame.

# %%
# para deleção da linha basta passar o índice
#df = df.drop(19)

#df.dropna()
#df.dropna(subset=['name', 'toy'])
#df.dropna(inplace=True)
df.drop(21414, inplace=True)
df.drop(21413, inplace=True)

df
# Out:
#       UF da ocorrências 2015 - 2022   Tipo Crime ocorrências 2015 - 2022  \
# 0                              Acre                              Estupro
# 1                              Acre                     Furto de veículo
# 2                              Acre                     Homicídio doloso
# 3                              Acre      Lesão corporal seguida de morte
# 4                              Acre       Roubo a instituição financeira
# ...                             ...                                  ...
# 21411                     Tocantins                     Homicídio doloso
# 21412                     Tocantins      Lesão corporal seguida de morte
# 21415                     Tocantins                     Roubo de veículo
# 21416                     Tocantins  Roubo seguido de morte (latrocínio)
# 21417                     Tocantins               Tentativa de homicídio
#
#        Ano da ocorrências 2015 - 2022  Ocorrências 2015 - 2022  \
# 0                              2022.0                       31
# 1                              2022.0                       50
# 2                              2022.0                       10
# 3                              2022.0                        0
# 4                              2022.0                        0
# ...                               ...                      ...
# 21411                          2015.0                       50
# 21412                          2015.0                        0
# 21415                          2015.0                       55
# 21416                          2015.0                        2
# 21417                             NaN                       42
#
#       UF da ocorrências 2022      Tipo Crime ocorrências 2022  \
# 0                       Acre                          Estupro
# 1                       Acre                 Furto de veículo
# 2                       Acre                 Homicídio doloso
# 3                       Acre  Lesão corporal seguida de morte
# 4                       Acre   Roubo a instituição financeira
# ...                      ...                              ...
# 21411                    NaN                              NaN
# 21412                    NaN                              NaN
# 21415                    NaN                              NaN
# 21416                    NaN                              NaN
# 21417                    NaN                              NaN
#
#        Ano da ocorrências 2022 Ocorrências 2022 UF da ocorrências 2021  \
# 0                       2022.0             31.0                   Acre
# 1                       2022.0             50.0                   Acre
# 2                       2022.0             10.0                   Acre
# 3                       2022.0              0.0                   Acre
# 4                       2022.0              0.0                   Acre
# ...                        ...              ...                    ...
# 21411                      NaN     Desconhecido                    NaN
# 21412                      NaN     Desconhecido                    NaN
# 21415                      NaN     Desconhecido                    NaN
# 21416                      NaN     Desconhecido                    NaN
# 21417                      NaN     Desconhecido                    NaN
#
#                Tipo Crime ocorrências 2021  ...        Tipo Crime  \
# 0           Roubo a instituição financeira  ...  Homicídio doloso
# 1                           Roubo de carga  ...  Homicídio doloso
# 2                         Roubo de veículo  ...  Homicídio doloso
# 3      Roubo seguido de morte (latrocínio)  ...  Homicídio doloso
# 4                   Tentativa de homicídio  ...  Homicídio doloso
# ...                                    ...  ...               ...
# 21411                                  NaN  ...               NaN
# 21412                                  NaN  ...               NaN
# 21415                                  NaN  ...               NaN
# 21416                                  NaN  ...               NaN
# 21417                                  NaN  ...               NaN
#
#        Ano do crime Sexo da Vítima Vitima do crime   Cód_IBGE  \
# 0            2022.0       Feminino             2.0  4100103.0
# 1            2022.0      Masculino             8.0  4100202.0
# 2            2022.0        Sexo NI             0.0  4100301.0
# 3            2022.0       Feminino             0.0  4100400.0
# 4            2022.0      Masculino            10.0  4100459.0
# ...             ...            ...             ...        ...
# 21411           NaN            NaN             NaN        NaN
# 21412           NaN            NaN             NaN        NaN
# 21415           NaN            NaN             NaN        NaN
# 21416           NaN            NaN             NaN        NaN
# 21417           NaN            NaN             NaN        NaN
#
#                  Município Sigla UF Região    Mês/Ano Vítimas
# 0                   Abatiá       PR    SUL 2018-01-01     0.0
# 1             Adrianópolis       PR    SUL 2018-01-01     1.0
# 2            Agudos Do Sul       PR    SUL 2018-01-01     0.0
# 3      Almirante Tamandaré       PR    SUL 2018-01-01     6.0
# 4       Altamira Do Paraná       PR    SUL 2018-01-01     0.0
# ...                    ...      ...    ...        ...     ...
# 21411                  NaN      NaN    NaN        NaT     NaN
# 21412                  NaN      NaN    NaN        NaT     NaN
# 21415                  NaN      NaN    NaN        NaT     NaN
# 21416                  NaN      NaN    NaN        NaT     NaN
# 21417                  NaN      NaN    NaN        NaT     NaN
#
# [21416 rows x 27 columns]

# %% [markdown]
# Também podemos remover uma coluna inteira com o comando (tips.drop), com isso vamos remover colunas com muitos valores "Desconhecidos".

# %%
#df = df.drop(columns=['Cód_IBGE'])
#df = df.drop(columns=['Município'])
#df = df.drop(columns=['Região'])
#df = df.drop(columns=['Sigla UF'])
#df = df.drop(columns=['Mês/Ano'])
#df = df.drop(columns=['Ano da ocorrências 2020'])
#df = df.drop(columns=['Ano da ocorrências 2021'])
#df = df.drop(columns=['Ano da ocorrências 2022'])
df = df.drop(columns=['Vítimas'])





df.head()
# Out:
#   UF da ocorrências 2015 - 2022 Tipo Crime ocorrências 2015 - 2022  \
# 0                          Acre                            Estupro
# 1                          Acre                   Furto de veículo
# 2                          Acre                   Homicídio doloso
# 3                          Acre    Lesão corporal seguida de morte
# 4                          Acre     Roubo a instituição financeira
#
#    Ano da ocorrências 2015 - 2022  Ocorrências 2015 - 2022  \
# 0                          2022.0                       31
# 1                          2022.0                       50
# 2                          2022.0                       10
# 3                          2022.0                        0
# 4                          2022.0                        0
#
#   UF da ocorrências 2022      Tipo Crime ocorrências 2022  Ocorrências 2022  \
# 0                   Acre                          Estupro              31.0
# 1                   Acre                 Furto de veículo              50.0
# 2                   Acre                 Homicídio doloso              10.0
# 3                   Acre  Lesão corporal seguida de morte               0.0
# 4                   Acre   Roubo a instituição financeira               0.0
#
#   UF da ocorrências 2021          Tipo Crime ocorrências 2021  \
# 0                   Acre       Roubo a instituição financeira
# 1                   Acre                       Roubo de carga
# 2                   Acre                     Roubo de veículo
# 3                   Acre  Roubo seguido de morte (latrocínio)
# 4                   Acre               Tentativa de homicídio
#
#    Ocorrências 2021 UF da ocorrências 2020      Tipo Crime ocorrências 2020  \
# 0               1.0                   Acre                          Estupro
# 1               0.0                   Acre                 Furto de veículo
# 2              91.0                   Acre                 Homicídio doloso
# 3               0.0                   Acre  Lesão corporal seguida de morte
# 4              11.0                   Acre   Roubo a instituição financeira
#
#    Ocorrências 2020 UF crime        Tipo Crime  Ano do crime Sexo da Vítima  \
# 0              18.0     Acre  Homicídio doloso        2022.0       Feminino
# 1              23.0     Acre  Homicídio doloso        2022.0      Masculino
# 2              46.0     Acre  Homicídio doloso        2022.0        Sexo NI
# 3               0.0     Acre  Homicídio doloso        2022.0       Feminino
# 4               0.0     Acre  Homicídio doloso        2022.0      Masculino
#
#    Vitima do crime
# 0              2.0
# 1              8.0
# 2              0.0
# 3              0.0
# 4             10.0

# %% [markdown]
# ## Conversão de tipos

# %% [markdown]
# Para converter as colunas para os tipos adequados, usamos o método `astype`. Podemos tanto aplicar a uma coluna por vez ou em várias colunas representadas por um dicionário. O código abaixo exemplifica as duas abordagens:

# %%
df = df.astype({'Vitima do crime': float, 'Ano do crime': float, 'Ocorrências 2020': object, 'Ocorrências 2021': object,'Ocorrências 2022': float,'Ano da ocorrências 2015 - 2022': float})

# %%
Os dados nulos não foram retirados, pois a coluna de 2015 - 2022 é maior que as outras, tratando de um total

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21418 entries, 0 to 21417
# Data columns (total 18 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   UF da ocorrências 2015 - 2022       21418 non-null  object
#  1   Tipo Crime ocorrências 2015 - 2022  21418 non-null  object
#  2   Ano da ocorrências 2015 - 2022      21417 non-null  float64
#  3   Ocorrências 2015 - 2022             21418 non-null  int64
#  4   UF da ocorrências 2022              1184 non-null   object
#  5   Tipo Crime ocorrências 2022         1184 non-null   object
#  6   Ocorrências 2022                    1184 non-null   float64
#  7   UF da ocorrências 2021              2864 non-null   object
#  8   Tipo Crime ocorrências 2021         2864 non-null   object
#  9   Ocorrências 2021                    2864 non-null   object
#  10  UF da ocorrências 2020              2880 non-null   object
#  11  Tipo Crime ocorrências 2020         2880 non-null   object
#  12  Ocorrências 2020                    2880 non-null   object
#  13  UF crime                            18342 non-null  object
#  14  Tipo Crime                          18342 non-null  object
#  15  Ano do crime                        18342 non-null  float64
#  16  Sexo da Vítima                      18342 non-null  object
#  17  Vitima do crime                     18342 non-null  float64
# dtypes: float64(4), int64(1), object(13)
# memory usage: 2.9+ MB

# %% [markdown]
# Com todos os tipos convertidos corretamente, podemos aplicar funções estatísticas e exibir corretamente os valores em gráficos como mostrado abaixo:

# %%
df
# Out:
#       UF da ocorrências 2015 - 2022   Tipo Crime ocorrências 2015 - 2022  \
# 0                              Acre                              Estupro
# 1                              Acre                     Furto de veículo
# 2                              Acre                     Homicídio doloso
# 3                              Acre      Lesão corporal seguida de morte
# 4                              Acre       Roubo a instituição financeira
# ...                             ...                                  ...
# 21413                     Tocantins       Roubo a instituição financeira
# 21414                     Tocantins                       Roubo de carga
# 21415                     Tocantins                     Roubo de veículo
# 21416                     Tocantins  Roubo seguido de morte (latrocínio)
# 21417                     Tocantins               Tentativa de homicídio
#
#        Ano da ocorrências 2015 - 2022  Ocorrências 2015 - 2022  \
# 0                              2022.0                       31
# 1                              2022.0                       50
# 2                              2022.0                       10
# 3                              2022.0                        0
# 4                              2022.0                        0
# ...                               ...                      ...
# 21413                          2015.0                        6
# 21414                          2015.0                        1
# 21415                          2015.0                       55
# 21416                          2015.0                        2
# 21417                             NaN                       42
#
#       UF da ocorrências 2022      Tipo Crime ocorrências 2022  \
# 0                       Acre                          Estupro
# 1                       Acre                 Furto de veículo
# 2                       Acre                 Homicídio doloso
# 3                       Acre  Lesão corporal seguida de morte
# 4                       Acre   Roubo a instituição financeira
# ...                      ...                              ...
# 21413                    NaN                              NaN
# 21414                    NaN                              NaN
# 21415                    NaN                              NaN
# 21416                    NaN                              NaN
# 21417                    NaN                              NaN
#
#        Ocorrências 2022 UF da ocorrências 2021  \
# 0                  31.0                   Acre
# 1                  50.0                   Acre
# 2                  10.0                   Acre
# 3                   0.0                   Acre
# 4                   0.0                   Acre
# ...                 ...                    ...
# 21413               NaN                    NaN
# 21414               NaN                    NaN
# 21415               NaN                    NaN
# 21416               NaN                    NaN
# 21417               NaN                    NaN
#
#                Tipo Crime ocorrências 2021 Ocorrências 2021  \
# 0           Roubo a instituição financeira              1.0
# 1                           Roubo de carga              0.0
# 2                         Roubo de veículo             91.0
# 3      Roubo seguido de morte (latrocínio)              0.0
# 4                   Tentativa de homicídio             11.0
# ...                                    ...              ...
# 21413                                  NaN              NaN
# 21414                                  NaN              NaN
# 21415                                  NaN              NaN
# 21416                                  NaN              NaN
# 21417                                  NaN              NaN
#
#       UF da ocorrências 2020      Tipo Crime ocorrências 2020  \
# 0                       Acre                          Estupro
# 1                       Acre                 Furto de veículo
# 2                       Acre                 Homicídio doloso
# 3                       Acre  Lesão corporal seguida de morte
# 4                       Acre   Roubo a instituição financeira
# ...                      ...                              ...
# 21413                    NaN                              NaN
# 21414                    NaN                              NaN
# 21415                    NaN                              NaN
# 21416                    NaN                              NaN
# 21417                    NaN                              NaN
#
#       Ocorrências 2020 UF crime        Tipo Crime Ano do crime Sexo da Vítima  \
# 0                 18.0     Acre  Homicídio doloso       2022.0       Feminino
# 1                 23.0     Acre  Homicídio doloso       2022.0      Masculino
# 2                 46.0     Acre  Homicídio doloso       2022.0        Sexo NI
# 3                  0.0     Acre  Homicídio doloso       2022.0       Feminino
# 4                  0.0     Acre  Homicídio doloso       2022.0      Masculino
# ...                ...      ...               ...          ...            ...
# 21413              NaN      NaN               NaN          NaN            NaN
# 21414              NaN      NaN               NaN          NaN            NaN
# 21415              NaN      NaN               NaN          NaN            NaN
# 21416              NaN      NaN               NaN          NaN            NaN
# 21417              NaN      NaN               NaN          NaN            NaN
#
#       Vitima do crime
# 0                 2.0
# 1                 8.0
# 2                 0.0
# 3                 0.0
# 4                10.0
# ...               ...
# 21413             nan
# 21414             nan
# 21415             nan
# 21416             nan
# 21417             nan
#
# [21418 rows x 18 columns]

# %% [markdown]
# ## Escrevendo os dados limpos no disco
#
# Para salvar os dados limpos em um arquivo, usamos o método `to_xlsx`, como no exemplo abaixo:

# %%
df.to_excel('C:/Users/lucas.soares/Documents/Nova Pasta/SegurançaBrasilLimpo.xlsx', index=False)
